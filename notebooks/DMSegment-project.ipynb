# %%
# Mount drive,
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install python dependencies
# %cd /content/drive/MyDrive/DMDetect/
# %pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/DMDetect
# ...

# %%
# Go to project folder
# %cd /content/drive/MyDrive/DMDetect/python/
# Out:
# /content/drive/MyDrive/DMDetect/python

# %%
# NOTE: This is EXTREMELY SLOW TO DO IN COLAB! This is because writing from the drive is slow (reading is also a bit slow, one-by-one)... 
# Should preprocess locally, if possible, and upload the preprocessed data to the expected location
# Process data
# !python create_data.py
# Out:
# 2021-04-10 20:36:17.929455: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# DM: 100% 150/150 [30:24<00:00, 12.16s/it]

# %%
# Train segmentation model
# !python train_seg.py
# Out:
# 2021-04-10 21:41:03.762192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
# Current model run:
# 100421_214107_bs_2_arch_unet_img_1024_nbcl_5_gamma_3_aug_horz,gamma_drp_0,1_
#
# 2021-04-10 21:41:07.546372: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-10 21:41:07.547241: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-10 21:41:07.580453: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-10 21:41:07.581017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# ...

# %%
# Evaluate trained segmentation model
# %matplotlib inline
# !python eval_seg.py
# Out:
# 2021-04-10 21:47:36.185161: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-10 21:47:39.073906: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-10 21:47:39.074751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-10 21:47:39.108609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-10 21:47:39.109177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...
